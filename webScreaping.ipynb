# %%
###  WEB SCRAPTING

import requests

url="https://www.scrapethissite.com/pages/simple/"

res=requests.get(url)

res

# print(res.status_code)

# if(res.status_code!=200):
#     print("some thing is wrong ")
# else:
#     # print(res.text)
#     print(res.headers)

with open ("sraped_data/data.html",'w',encoding="utf-8") as f:
    f.write(res.text)


print("html file added correctlly")
# Out:
# html file added correctlly
