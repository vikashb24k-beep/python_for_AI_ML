# %%
import numpy as np

# %%
## linear regression

class LinearRegression:
    def __init__(self,learning_rate=0.01,n_iter=1000):
        self.bias=None
        self.weights=None
        self.learning_rate=learning_rate
        self.n_iter=n_iter


    def fit(self,x,y):   # x_train , y_train
        m,n=x.shape  # no of rows and column

        # step1
        self.bias=0; # constant h(x)=bias + weight1*x1 + weight2*x2 + weight3*x3 + ....
        self.weights=np.zeros(n)    # [0,0,0,...n times] n is no of column or features

        # step2
        y_pred=self.bias + np.dot(x,self.weights)  
        
    def predict(self,):
